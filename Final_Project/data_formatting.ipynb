# %%
import pandas as pd

# %%
#Retrieve and format available lines
betting_data = pd.read_csv('stanford_2023_lines.csv')

#Only include Bovada lines
betting_data = betting_data[betting_data['LineProvider'].str.contains('Bovada', case=False, na=False)]

#Sort chronologically
betting_data = betting_data.sort_values(by=betting_data.columns[0], ascending=True)

betting_data = betting_data.reset_index(drop=True)

betting_data.to_csv('stanford_2023_lines_altered.csv', index=False)

betting_data.head(20)
# Out:
#            Id          HomeTeam  HomeScore    AwayTeam  AwayScore  \
# 0   401523988           Hawai'i         24    Stanford         37
# 1   401524003               USC         56    Stanford         10
# 2   401524016          Stanford         20     Arizona         21
# 3   401524024          Stanford          6      Oregon         42
# 4   401524029          Colorado         43    Stanford         46
# 5   401524036          Stanford          7        UCLA         42
# 6   401524042          Stanford         33  Washington         42
# 7   401524050  Washington State          7    Stanford         10
# 8   401524054      Oregon State         62    Stanford         17
# 9   401524061          Stanford         15  California         27
# 10  401524065          Stanford         23  Notre Dame         56
#
#    LineProvider  OverUnder  Spread         FormattedSpread  OpeningSpread  \
# 0        Bovada       54.5     2.5           Stanford -2.5            8.0
# 1        Bovada       70.0   -28.5               USC -28.5          -30.0
# 2        Bovada       59.5    13.0           Arizona -13.0           10.0
# 3        Bovada       61.0    27.0            Oregon -27.0           27.0
# 4        Bovada       59.0   -13.0          Colorado -13.0          -11.5
# 5        Bovada       51.5    17.0              UCLA -17.0           16.5
# 6        Bovada       62.0    28.0        Washington -28.0           26.5
# 7        Bovada       58.0   -14.0  Washington State -14.0          -13.5
# 8        Bovada       52.5   -21.5      Oregon State -21.5          -20.5
# 9        Bovada       53.5     7.0         California -7.0            4.5
# 10       Bovada       50.5    26.0        Notre Dame -26.0           24.5
#
#     OpeningOverUnder  HomeMoneyline  AwayMoneyline
# 0               58.5          235.0         -285.0
# 1               71.0       -10000.0         1600.0
# 2               59.0          290.0         -380.0
# 3               61.0         1200.0        -4000.0
# 4               59.0         -460.0          340.0
# 5               54.0          550.0         -850.0
# 6               59.5         1300.0        -5000.0
# 7               61.0         -575.0          400.0
# 8               54.5        -1800.0          850.0
# 9               57.5          210.0         -250.0
# 10              52.0         1100.0        -3300.0

# %%
num_rows, num_columns = betting_data.shape

print("Size of Betting Data")
print("")
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Size of Betting Data
#
# Number of rows: 11
# Number of columns: 13

# %%
#Retrieve game stats
game_stats = pd.read_csv('stanford_2023_gamestats.csv')

#Get rid of unnecessary columns and Sacramento State game since we don't have betting lines
game_stats = game_stats.drop(columns=['Season Type', 'Start Date', 
                                     'Start Time Tbd', 'Completed',
                                     'Neutral Site', 'Conference Game',
                                     'Attendance', 'Venue Id', 'Venue',
                                     'Home Id', 'Home Conference',
                                     'Home Division', 'Home Line Scores[0]',
                                     'Home Line Scores[1]', 'Home Line Scores[2]',
                                     'Home Line Scores[3]', 'Away Id',
                                     'Away Line Scores[0]', 'Away Line Scores[1]',
                                     'Away Line Scores[2]', 'Away Line Scores[3]',
                                     'Away Conference', 'Away Division', 'Highlights',
                                     'Notes'], index=2)

game_stats.to_csv('stanford_2023_gamestats_altered.csv', index=False)

game_stats.head(12)
# Out:
#            Id  Season  Week         Home Team  Home Points  \
# 0   401523988    2023     1           Hawai'i           24
# 1   401524003    2023     2               USC           56
# 3   401524016    2023     4          Stanford           20
# 4   401524024    2023     5          Stanford            6
# 5   401524029    2023     7          Colorado           43
# 6   401524036    2023     8          Stanford            7
# 7   401524042    2023     9          Stanford           33
# 8   401524050    2023    10  Washington State            7
# 9   401524054    2023    11      Oregon State           62
# 10  401524061    2023    12          Stanford           15
# 11  401524065    2023    13          Stanford           23
#
#     Home Post Win Prob  Home Pregame Elo  Home Postgame Elo   Away Team  \
# 0             0.010951              1241               1220    Stanford
# 1             0.998962              1817               1891    Stanford
# 3             0.193059              1271               1278     Arizona
# 4             0.001096              1278               1237      Oregon
# 5             0.649493              1293               1285    Stanford
# 6             0.000522              1245               1198        UCLA
# 7             0.282200              1198               1230  Washington
# 8             0.393676              1454               1435    Stanford
# 9             0.998545              1765               1830    Stanford
# 10            0.003792              1184               1179  California
# 11            0.000308              1179               1180  Notre Dame
#
#     Away Points  Away Post Win Prob  Away Pregame Elo  Away Postgame Elo  \
# 0            37            0.989049            1324.0             1345.0
# 1            10            0.001038            1345.0             1271.0
# 3            21            0.806941            1453.0             1446.0
# 4            42            0.998904            1782.0             1823.0
# 5            46            0.350507            1237.0             1245.0
# 6            42            0.999478            1671.0             1718.0
# 7            42            0.717800            1884.0             1852.0
# 8            10            0.606324            1230.0             1249.0
# 9            17            0.001455            1249.0             1184.0
# 10           27            0.996208            1426.0             1431.0
# 11           56            0.999692            2010.0             2009.0
#
#     Excitement Index
# 0           4.249206
# 1           2.266054
# 3           7.396189
# 4           3.294809
# 5           7.697020
# 6           2.328706
# 7           6.921231
# 8           7.107037
# 9           2.976712
# 10          4.761373
# 11          3.450513

# %%
num_rows, num_columns = game_stats.shape

print("Size of Game Stats Data")
print("")
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Size of Game Stats Data
#
# Number of rows: 11
# Number of columns: 14

# %%
adv_metrics = pd.read_csv('stanford_2023_advancedmetrics.csv')

adv_metrics = adv_metrics.drop(index=2)

adv_metrics.to_csv('stanford_2023_advancedmetrics_altered.csv', index=False)

adv_metrics.head(12)
# Out:
#        GameId  Week      Team          Opponent  Offense Plays  \
# 0   401523988     1  Stanford           Hawai'i             67
# 1   401524003     2  Stanford               USC             66
# 3   401524016     4  Stanford           Arizona             66
# 4   401524024     5  Stanford            Oregon             70
# 5   401524029     7  Stanford          Colorado             86
# 6   401524036     8  Stanford              UCLA             62
# 7   401524042     9  Stanford        Washington             80
# 8   401524050    10  Stanford  Washington State             70
# 9   401524054    11  Stanford      Oregon State             63
# 10  401524061    12  Stanford        California             57
# 11  401524065    13  Stanford        Notre Dame             73
#
#     Offense Drives  Offense Ppa  Offense TotalPPA  Offense SuccessRate  \
# 0               11     0.232013         15.544844             0.462687
# 1               14    -0.122133         -8.060770             0.393939
# 3               10     0.153373         10.122589             0.409091
# 4                9    -0.104485         -7.313962             0.357143
# 5               14     0.255788         21.997803             0.476744
# 6               13     0.023353          1.447905             0.322581
# 7               14     0.296445         23.715596             0.487500
# 8               11    -0.062424         -4.369673             0.300000
# 9               13     0.033653          2.120125             0.285714
# 10              12     0.040535          2.310467             0.298246
# 11              14    -0.090585         -6.612704             0.315068
#
#     Offense Explosiveness  ...  Defense PassingDowns SuccessRate  \
# 0                1.241753  ...                          0.357143
# 1                1.156977  ...                          0.500000
# 3                1.351993  ...                          0.400000
# 4                1.070678  ...                          0.500000
# 5                1.216817  ...                          0.368421
# 6                1.309574  ...                          0.464286
# 7                1.149510  ...                          0.285714
# 8                1.056761  ...                          0.208333
# 9                1.958142  ...                          0.500000
# 10               1.513605  ...                          0.360000
# 11               1.369987  ...                          0.600000
#
#     Defense PassingDowns Explosiveness  Defense RushingPlays Ppa  \
# 0                             2.376622                 -0.090585
# 1                             1.261221                  0.344632
# 3                             1.602847                  0.276542
# 4                             1.857898                  0.491598
# 5                             2.606326                  0.145651
# 6                             2.084247                  0.150228
# 7                             2.602832                 -0.141158
# 8                             2.463283                 -0.260834
# 9                             2.581481                  0.523507
# 10                            1.948049                  0.029610
# 11                            1.521522                  0.412654
#
#     Defense RushingPlays TotalPPA  Defense RushingPlays SuccessRate  \
# 0                       -0.905847                          0.200000
# 1                        9.994327                          0.551724
# 3                        9.678955                          0.628571
# 4                       13.764751                          0.607143
# 5                        4.515175                          0.580645
# 6                        7.511380                          0.500000
# 7                       -3.670120                          0.461538
# 8                       -5.216680                          0.400000
# 9                       19.369764                          0.594595
# 10                       1.302851                          0.454545
# 11                      19.807405                          0.750000
#
#     Defense RushingPlays Explosiveness  Defense PassingPlays Ppa  \
# 0                             1.325602                  0.251531
# 1                             1.009559                  0.654798
# 3                             0.795073                  0.069661
# 4                             1.152901                  0.659347
# 5                             0.501510                  0.445155
# 6                             0.863195                  0.447843
# 7                             0.392749                  0.615088
# 8                             0.584880                  0.155324
# 9                             1.349652                  0.734810
# 10                            0.922140                  0.435741
# 11                            0.740501                  0.660995
#
#     Defense PassingPlays TotalPPA  Defense PassingPlays SuccessRate  \
# 0                       14.337270                          0.385965
# 1                       24.227540                          0.621622
# 3                        2.229158                          0.437500
# 4                       21.758447                          0.636364
# 5                       22.702882                          0.490196
# 6                       17.018031                          0.500000
# 7                       22.143173                          0.500000
# 8                        6.678937                          0.372093
# 9                       21.309504                          0.517241
# 10                      16.993896                          0.435897
# 11                       9.914932                          0.533333
#
#     Defense PassingPlays Explosiveness
# 0                             1.731827
# 1                             1.321682
# 3                             1.209872
# 4                             1.342475
# 5                             1.631422
# 6                             1.610731
# 7                             1.830977
# 8                             1.353035
# 9                             1.982867
# 10                            1.830031
# 11                            2.150736
#
# [11 rows x 60 columns]

# %%
num_rows, num_columns = adv_metrics.shape

print("Size of Advanced Metrics Data")
print("")
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Size of Advanced Metrics Data
#
# Number of rows: 11
# Number of columns: 60

# %%
team_stats = pd.read_csv('stanford_2023_teamstats.csv')

team_stats = team_stats[team_stats['School'] == 'Stanford']

# Initialize a dictionary to collect data by game ID
data = []

# Iterate over each unique game ID
for game_id in team_stats['Game Id'].unique():
    # Filter rows for the current game ID
    game_data = team_stats[team_stats['Game Id'] == game_id]
    
    # Create a dictionary to store all stats for this game
    row = {'Game Id': game_id, 'School': 'Stanford'}
    
    # Loop through each row in this subset to add stats to the dictionary
    for _, stat_row in game_data.iterrows():
        # Use the stat category as the column name and assign the stat value
        stat_category = stat_row['Stat Category']
        stat_value = stat_row['Stat']
        row[stat_category] = stat_value
    
    # Append the constructed row to our data list
    data.append(row)

# Convert the list of dictionaries to a DataFrame
team_stats = pd.DataFrame(data)

team_stats = team_stats.sort_values(by=team_stats.columns[0], ascending=True)

team_stats = team_stats.fillna(0)

team_stats = team_stats.drop(index=8)

team_stats = team_stats.reset_index(drop=True)

team_stats.to_csv('stanford_2023_teamstats_altered.csv', index=False)

team_stats.head(40)
# Out:
#       Game Id    School rushingTDs puntReturnYards puntReturnTDs puntReturns  \
# 0   401523988  Stanford          2              14             0           1
# 1   401524003  Stanford          1               0             0           0
# 2   401524016  Stanford          2               0             0           0
# 3   401524024  Stanford          0               0             0           0
# 4   401524029  Stanford          2               0             0           0
# 5   401524036  Stanford          0               1             0           1
# 6   401524042  Stanford          3               0             0           0
# 7   401524050  Stanford          1               8             0           1
# 8   401524054  Stanford          1               9             0           1
# 9   401524061  Stanford          0              16             0           2
# 10  401524065  Stanford          2               0             0           0
#
#    passingTDs kickReturnYards kickReturnTDs kickReturns  ... yardsPerPass  \
# 0           2               0             0           0  ...          6.9
# 1           0              57             0           3  ...          5.6
# 2           0               0             0           0  ...          7.7
# 3           0              23             0           1  ...          5.5
# 4           4              22             0           2  ...          8.1
# 5           1             122             0           8  ...            6
# 6           1              31             0           2  ...          7.2
# 7           0               9             0           1  ...          4.4
# 8           1               0             0           1  ...          7.6
# 9           1               0             0           0  ...          5.4
# 10          0               0             0           0  ...          5.1
#
#    completionAttempts netPassingYards totalYards fourthDownEff thirdDownEff  \
# 0               25-36             248        406           0-0       14-Jun
# 1              25-Oct             140        349           0-1       13-Apr
# 2               18-32             246        358         1-Jan       16-Jul
# 3               14-24             133        222         6-Mar       18-Jun
# 4               28-49             399        523           0-1       18-Oct
# 5               27-45             268        292           0-4       11-Jan
# 6               31-51             367        495         3-Jan       16-May
# 7               16-32             142        217         3-Feb       18-Jun
# 8               14-32             242        324           0-1       13-Mar
# 9               18-35             188        289         2-Jan       16-May
# 10              21-42             216        359         4-Jan       16-May
#
#    firstDowns interceptionYards interceptionTDs passesIntercepted
# 0          24                 0               0                 0
# 1          20                 0               0                 0
# 2          19                 0               0                 0
# 3          16                 0               0                 0
# 4          29                 0               0                 1
# 5          15                 0               0                 0
# 6          26                 0               0                 1
# 7          18                10               0                 1
# 8          18                 0               0                 0
# 9          12                25               0                 1
# 10         19                 9               0                 2
#
# [11 rows x 37 columns]

# %%
num_rows, num_columns = team_stats.shape

print("Size of Team Stats Data")
print("")
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Size of Team Stats Data
#
# Number of rows: 11
# Number of columns: 37
